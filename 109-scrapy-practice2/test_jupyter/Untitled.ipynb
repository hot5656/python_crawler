# %%
import requests
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36'
}
res = requests.get('https://www.momoshop.com.tw/category/DgrpCategory.jsp?d_code=2900400054&CPHOT=Y&flag=L&sourcePageType=4', headers=headers)
# res.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n\n<!DOCTYPE HTML>\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n<html lang="zh">\n<head>\n<link rel="shortcut icon" href="/main/favicon.ico"/>\n<link rel="Bookmark" href="/main/favicon.ico"/>\n<link rel="icon" href="/main/favicon.ico" type="image/ico"/>\n<link rel="search" href="/search/openSearch.xml" type="application/opensearchdescription+xml" title= momo購物網 - 好評推薦 - 2023年2月/>\n\n\n<link rel="canonical" href="https://www.momoshop.com.tw/category/DgrpCategory.jsp?d_code=2900400054">\n<link rel="alternate" media="only screen and (max-width: 640px)" href="https://m.momoshop.com.tw/category.momo?cphot=y&cn=2900400054">\n\n\n<title>&#25240;&#20729;&#21048;&#29105;&#37559;,&#39208;&#38263;&#25512;&#34214;,&#21560;&#22645;&#22120;,&#23478;&#38651;-momo&#36092;&#29289;&#32178;  - 好評推薦 - 2023年2月</title>\n\n\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\n<meta name="Title" content="&#25240;&#20729;&#21048;&#29105;&#37559;,&#39208;&#38263;&#25512;&#34214;,&#21560;&#22645;&#22120;,&#23478;&#38651;-momo&#36092;&#29289;&#32178; ">\n<meta name="Author" content="momo購物網">\n<meta name="Subject" content="momoshop,momo購物網">\n<meta name="Description" content="&#25240;&#20729;&#21048;&#29105;&#37559;,&#39208;&#38263;&#25512;&#34214;,&#21560;&#22645;&#22120;,&#23478;&#38651;,TV&#29105;&#37559;&#29694;&#25240;$100,&#26412;&#36913;&#26032;&#21697;,&#26412;&#36913;&#26032;&#38477;&#20729;TV&#29105;&#37559;&#29694;&#25240;$100,&#26412;&#36913;&#26032;&#21697;,&#26412;&#36913;&#26032;&#38477;&#20729;&#21508;&#24335;&#35215;&#26684;&#31278;&#39006;,&#33287;LG &#27138;&#37329;,Gtech&#23567;&#32160;&#38500;&#36451;&#22823;&#20840;&#37197;,&#21152;&#30908;&#36865;&#22645;&#36451;&#38957;&#29105;&#38272;&#21697;&#29260;,&#20778;&#24800;&#20415;&#23452;&#22909;&#20729;&#26684;,&#20540;&#24471;&#25512;&#34214;&#65281;">\n<meta name="Keywords" content="&#25240;&#20729;&#21048;&#29105;&#37559;,&#39208;&#38263;&#25512;&#34214;,&#21560;&#22645;&#22120;,&#23478;&#38651;,TV&#29105;&#37559;&#29694;&#25240;$100,&#26412;&#36913;&#26032;&#21697;,&#26412;&#36913;&#26032;&#38477;&#20729;">\n<meta name="Language" content="Tradition Chinese">\n<meta name="Abstract" content="momoshop,momo購物網">\n<meta name="Copyright" content="momoshop,momo購物網">\n<meta name="Designer" content="momoshop,momo購物網">\n<meta name="Publisher" content="momoshop,momo購物網">\n<meta name="Distribution" content="Global">\n<meta name="Robots" content="All">\n<meta name="theme-color" content="#D62872">\n<meta name="msvalidate.01" content="EBED0A1510C08C233B5D03D91DA5499D">\n\n<!-- zKBBexYOFCj102YjEZr2_011xHY -->\n\n<meta property="og:type" content="article">\n<meta property="og:image" content="https://img1.momoshop.com.tw/ecm/img/cmm/fb-image-share.jpg">\n<meta property="og:site_name" content="momo購物網">\n<meta property="og:description" content="折價券熱銷,TV熱銷現折$100,本週新品,本週新降價各式規格種類,與LG 樂金,Gtech小綠除蹣大全配,加碼送塵蹣頭熱門品牌,優惠便宜好價格,值得推薦！">\n<meta property="og:url" content="">\n\n<meta property="og:title" content="&#25240;&#20729;&#21048;&#29105;&#37559; - momo&#36092;&#29289;&#32178;">\n\n\n<!-- Facebook AppLink(Deep Link) -->\n\n<meta property="al:android:url" content="momo.app://momoshop?status=0&goodsUrl=https://m.momoshop.com.tw/category.momo?cn=2900400054&d_code=2900400054&CPHOT=Y&flag=L&sourcePageType=4" />\n<meta property="al:android:package" content="com.momo.mobile.shoppingv2.android" />\n<meta property="al:android:app_name" content="momo購物網" />\n<meta property="al:ios:url" content="momo.app://momoshop?status=0&goodsUrl=https://m.momoshop.com.tw/category.momo?cn=2900400054&d_code=2900400054&CPHOT=Y&flag=L&sourcePageType=4" />\n<meta property="al:ios:app_store_id" content="861796017" />\n<meta property="al:ios:app_name" content="momo購物網" />\n<me ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')

# %%
ary = []
for good in soup.select('.eachGood'):
#     print(good)
    title = good.select_one('.prdName').get('title')
    price = good.select_one('.prdPrice').text
    icon = good.select_one('.iconArea').text
    ary.append({
        'title':title,
        'price': price,
        'icon':icon
    })
#     print(title, price, icon)
#     print("===========================")
print(ary)
# Out:
# [{'title': '【小米有品】SWDK速吸拖四合一無線吸塵洗地機(乾濕兩用 可替換電池)', 'price': '$4,999', 'icon': '折價券登記贈品'}, {'title': '【Electrolux 伊萊克斯】Well Q6無線吸塵器(WQ61-1EDB)', 'price': '$6,990', 'icon': '折價券登記贈品'}, {'title': '【Bmxmao】MAO Clean M7 旗艦25kPa 電動濕拖無線吸塵器-豪華16配件組(除蹣/雙電池)', 'price': '$10,336', 'icon': '折價券登記贈品'}, {'title': '【BISSELL 必勝】四合一吸塵拖地洗地機17135(乾濕兩用)', 'price': '$5,999', 'icon': '折價券登記贈品'}, {'title': '【Electrolux 伊萊克斯】超級完美管家吸塵器-HEPA進化版(夢幻粉紅ZB3314AK)', 'price': '$6,990', 'icon': '速折價券登記贈品'}, {'title': '【THOMSON】雙電池旗艦版電控濕拖無線吸塵器(TM-SAV52D)', 'price': '$8,111', 'icon': '折價券登記贈品'}, {'title': '【HERAN 禾聯】智慧感應無線吸塵器(HVC-35EP010B)', 'price': '$3,777', 'icon': '折價券登記贈品'}, {'title': '【Bmxmao】MAO Clean M3 入門首選16kPa超強吸力 無線手持吸塵器', 'price': '$2,966', 'icon': '折價券登記贈品'}, {'title': '【Bmxmao】MAO Clean M3 雙電池升級16kPa超強吸力 無線手持吸塵器', 'price': '$4,288', 'icon': '折價券登記贈品'}, {'title': '【IRIS OHYAMA 愛麗思歐雅瑪】i10高效兩用充電式直立式吸塵器 IC-SLDCP9(充電式 直立式 超強吸力 強效)', 'price': '$2,999', 'icon': '折價券登記贈品'}, {'title': '【HERAN禾聯新機塵蹣吸頭組】智慧感應雙HEPA無線吸塵器(HVC-35EP010)', 'price': '$4,288', 'icon': '折價券登記贈品'}, {'title': '【Kolin 歌林】直立手持兩用吸塵器(KTC-SD1921)【年度CP值最高 月銷破千台！！！】', 'price': '$649', 'icon': '速折價券登記贈品'}, {'title': '【HERAN 禾聯】自動牽引四合一無線洗地機(HWC-22EP050)', 'price': '$5,888', 'icon': '折價券登記贈品'}, {'title': '【Electrolux 伊萊克斯】極適家居700直立濕拖吸塵器(EFS71435 靜謐棕)', 'price': '$21,900', 'icon': '折價券登記贈品'}, {'title': '【BISSELL 必勝】X7五合一無線吸塵拖地洗地機(2832T)', 'price': '$17,990', 'icon': '折價券登記贈品'}, {'title': '【Electrolux 伊萊克斯】極適家居900系列無線濕拖吸塵器(EFP91824BU 淨河藍)', 'price': '$20,900', 'icon': '折價券登記贈品'}, {'title': '【IRIS OHYAMA 愛麗思歐雅瑪】大拍3.5偵測除蹣機HEPA13銀離子限定版IC-FAC2', 'price': '$2,490', 'icon': '速折價券登記贈品'}, {'title': '【Electrolux 伊萊克斯】Pure Q9-P雙效勁亮吸塵器(PQ92-3BWF)', 'price': '$16,900', 'icon': '折價券登記贈品'}, {'title': '【Electrolux 伊萊克斯】極適家居900系列無線濕拖吸塵器-琥珀棕(EFP91835)', 'price': '$25,900', 'icon': '折價券登記贈品'}, {'title': '【Bmxmao】MAO Clean M3 入門首選16kPa超強吸力 無線手持吸塵器', 'price': '$3,666', 'icon': '折價券登記贈品'}, {'title': '【Electrolux 伊萊克斯】極適家居700直立濕拖吸塵器(EFS71423 沉穩灰)', 'price': '$16,900', 'icon': '折價券登記贈品'}, {'title': '【Bmxmao】MAO Clean M3 入門首選16kPa超強吸力 無線手持吸塵器(直流無刷馬達/輕量簡配)', 'price': '$4,688', 'icon': '折價券登記贈品'}, {'title': '【LG 樂金】CordZero A9 K系列集塵壓縮版濕拖無線吸塵器A9K-MOP(鐵灰)', 'price': '$18,900', 'icon': '折價券登記'}, {'title': '【Bmxmao】MAO Clean M6 嶄新升級 無線手持吸塵器-豪華15配件組(除蹣/雙電池/寵物刷)', 'price': '$5,999', 'icon': '折價券登記贈品'}, {'title': '【Electrolux 伊萊克斯】極適家居700直立濕拖吸塵器(EFS71425WH 珍珠白)', 'price': '$19,900', 'icon': '折價券登記贈品'}, {'title': '【Bmxmao】MAO Clean M1 吸塵+吹氣 超強吸力 車用無線吸塵器-6組吸頭/附收納包', 'price': '$4,980', 'icon': '速折價券登記贈品'}, {'title': '【Panasonic 國際牌】輕量型無線吸塵器(MC-A13G)', 'price': '$7,490', 'icon': '折價券登記贈品'}, {'title': '【HERAN 禾聯】智慧感應無線吸塵器大全配組合(HVC-45EP050B大全配組合)', 'price': '$8,990', 'icon': ''}]

# %%
import pandas
df = pandas.DataFrame(ary)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import pandas
#       2 df = pandas.DataFrame(ary)
#       3 df.head()
#
# ModuleNotFoundError: No module named 'pandas'
